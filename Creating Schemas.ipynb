# %%
schemas = ["Bronze", "Silver", "Gold"]
catalogs = ["Dev_assessment", "Prod_Assessment", "qa_Assessment"]

for catalog in catalogs:
    for schema in schemas:
        spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog}.{schema}")
